# %%
MY_SECRET_KEY="Bm2KhsvRDaVufbK4VFGQ"

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
rf = Roboflow(api_key=MY_SECRET_KEY)
project = rf.workspace("-jwzpw").project("continuous_fire")
dataset = project.version(6).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=C:/Users/12/Desktop/NewBrand/Fire/continuous_fire-6/data.yaml epochs=1 imgsz=640 plots=True
# Out:
# ^C

# %%
# VIEW MODEL TRANING CHARTS
Image(filename=f'Fire/runs/detect/train4/results.png', width=600)
#Dont Forget To Enter Your Train Path
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 # VIEW MODEL TRANING CHARTS
# ----> 2 Image(filename=f'Fire/runs/detect/train4/results.csv', width=600)
#       3 #Dont Forget To Enter Your Train Path
#
# File c:\Users\12\Desktop\NewBrand\venv\Lib\site-packages\IPython\core\display.py:961, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     958 self.embed = embed if embed is not None else (url is None)
#     960 if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 961     raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     962 if self.embed:
#     963     self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'csv' image format

# %%
# VALIDATION
#if Getting Error Check It In Terminal Okk !!!!
# !yolo task=detect mode=val model=runs/detect/train4/weights/best.pt data=continuous_fire-6/data.yaml
